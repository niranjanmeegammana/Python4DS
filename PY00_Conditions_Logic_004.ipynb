# %% [markdown]
# # Conditions and Logic

# %%
# Applying logic using44 the IF statement
name = 'Nick'
if name == 'Neil Armstrong':
    print('Sup not Neil')

# %%
n=5
if n > 5:
  print ('n > 5')
else:
  print('n < 5 or n=5')
# Out:
# n < 5 or n=5

# %%
n=5
if n < 5 : 
  print('n < 5')
elif n > 5 :
  print(n > 5)
else:
  print('n=5')
# Out:
# n=5

# %%
probability = 0.1
# Probability is greater than 0.5
if probability >= 0.5:
    print(True)
    
# Print out a statement is probability is below
elif probability < 0: 
    print('Check yo probabilities')
    
# Anything else
else:     
    print(False)
# Out:
# False

# %%
# Create a list of names
names = ['neil armstrong', 'buzz aldrin', 'sally ride', 'yuri gagarin', 'elon musk'] 
if 'elon musk' in names:
    # Using Python escapes
    print("Elon\'s here")
# Out:
# Elon's here

# %%
var = 100
if var < 200:
   print ("Expression value is less than 200")
   if var == 150:
      print ("Which is 150")
   elif var == 100:
      print ("Which is 100")
   elif var == 50:
      print ("Which is 50")
   elif var < 50:
      print ("Expression value is less than 50")
else:
   print ("Could not find true expression")

print ("Good bye!")
# Out:
# Expression value is less than 200
# Which is 100
# Good bye!

# %%
a = b = c = 100

print (a)
print (b)
print (c)
# Out:
# 100
# 100
# 100

# %%
a,b,c = 1,2,"Ama Fernando"

print (a)
print (b)
print (c)
# Out:
# 1
# 2
# Ama Fernando
