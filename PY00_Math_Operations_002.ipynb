# %% [markdown]
# # Math

# %%
# Create two variables
math_value_1 = 1235456
math_value_2 = 5678914

# %%
# Addition
math_value_1 + math_value_2
# Out:
# 6914370

# %%
# Subtraction 
math_value_1 - math_value_2
# Out:
# -4443458

# %%
# Division
math_value_2 / math_value_1
# Out:
# 4.596613719954414

# %%
# Dividing with the Integral Result
math_value_2 // math_value_1
# Out:
# 4

# %%
# Modulus / Modulo
math_value_2 % math_value_1
# Out:
# 737090

# %%
math_value_2 - math_value_1*4
# Out:
# 737090

# %%
# Multiplication
math_value_1 * math_value_2
# Out:
# 7016048374784

# %%
# Power
math_value_1 ** 3
# Out:
# 1885740153297698816

# %%
# Round 
round(1212121.789123456, 2)
# Out:
# 1212121.79

# %%
# Absolute Values
abs(-91123154987978)
# Out:
# 91123154987978

# %%
# Minimum - smallest value 
min(121,8989,1212,5464,8974231,2121)
# Out:
# 121

# %%
# Maximum
max(121,8989,1212,5464,8974231,2121)
# Out:
# 8974231

# %%
# Import the math package
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.sqrt??
# Out:
# Object `math.sqrt` not found.

# %%
#'str' and 'int' objects cannot be concatenated

"a" + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b59eb05b3eb1> in <module>
#       1 #'str' and 'int' objects cannot be concatenated
#       2
# ----> 3 "a" + 4
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Convert int object to a str type and concatenate
"a" + str(4)
# Out:
# 'a4'
