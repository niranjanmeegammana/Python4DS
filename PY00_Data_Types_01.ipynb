# %% [markdown]
# # Data Types

# %%
# This is declaring a variable as a STRING 
string_variable = 'Sri Lanka'
print(string_variable)
# Out:
# Sri Lanka

# %%
type(string_variable)
# Out:
# str

# %%
# This is declaring a variable as an Integer
integer_variable = 1238
type(integer_variable)
# Out:
# int

# %%
integer_variable + 10
# Out:
# 1248

# %%
# This is declaring a variable as a Float
float_variable = 128.126
type(float_variable)
# Out:
# float

# %%
# This is assigning a Boolean value to a variable
bool_variable = bool(0)
type(bool_variable)
# Out:
# bool

# %%
bool_variable
# Out:
# False

# %%
# This is creating a list variable
list_variable = [1, 2, 3, 123.44, 85.4, 22.1, 1,2,3,1,2,3]
type(list_variable)
# Out:
# list

# %%
list_variable[5] = 123

# %%
list_variable
# Out:
# [1, 2, 3, 123.44, 85.4, 22.1, 1, 2, 3, 1, 2, 3]

# %%
# Create a TUPLE variable, IMMUTABLE = you can't change the values
tuple_variable = (1, 2, 3, 123.44, 85.4, 22.1, 3)
type(tuple_variable)
# Out:
# tuple

# %%
tuple_variable
# Out:
# (1, 2, 3, 123.44, 85.4, 22.1, 3)

# %%
# This is creating a SET variable, IMMUTABLE = you can't change the values, No DUPLICATES!
set_variable = {1, 2, 3, 123.44, 85.4, 22.1, 3}
type(set_variable)
# Out:
# set

# %%
# Type casting list to set back to list to get rid of duplicates
type(list(set(list_variable)))
# Out:
# list

# %%
# Defining a dictionary variable
dict_variable = {'name':"Ama", 'favourite_color':'red', 'favourite_number':20}
type(dict_variable)
# Out:
# dict

# %%
dict_variable['favourite_number']
# Out:
# 20

# %%
fit_models = {}

# %%
tuple(list_variable)
# Out:
# (1, 2, 3, 123.44, 85.4, 22.1, 1, 2, 3, 1, 2, 3)

# %% [markdown]
# # Lists

# %%
# Create
names = ['Ama', 'Bima', 'Sima', 'Yuma', 'Rima']

# %%
# Read 
names
# Out:
# ['Ama', 'Bima', 'Sima', 'Yuma', 'Rima']

# %%
# Reading using Indexing
names[0]
# Out:
# 'Ama'

# %%
names[-1]
# Out:
# 'Rima'

# %%
len(names)
# Out:
# 5

# %%
names[-1] = 'niko'
names
# Out:
# ['Ama', 'Bima', 'Sima', 'Yuma', 'niko']

# %%
names.append('Riko')

# %%
names
# Out:
# ['Ama', 'Bima', 'Sima', 'Yuma', 'niko', 'Riko']

# %%
names.insert(3, 'Jako')

# %%
names
# Out:
# ['Jako', 'Ama', 'Bima', 'Jako', 'Jako', 'Sima', 'Yuma', 'niko', 'Riko']

# %%
# Delete

# %%
del names[-2]

# %%
names
# Out:
# ['Jako', 'Ama', 'Bima', 'Jako', 'Jako', 'Sima', 'Yuma', 'Riko']

# %% [markdown]
# # Dictionaries

# %%
# Create
astronaut = {
    "name":"elon", 
    "suit_size":"large", 
    "allergies":"peanuts"
}

# %%
# Read

# %%
astronaut
# Out:
# {'name': 'elon musk', 'suit_size': 'large', 'allergies': 'peanuts'}

# %%
astronaut['suit_size']
# Out:
# 'large'

# %%
astronaut.keys()
# Out:
# dict_keys(['name', 'suit_size', 'allergies'])

# %%
astronaut.values()
# Out:
# dict_values(['elon', 'large', 'peanuts'])

# %%
# Update

# %%
astronaut['allergies'] = 'mango'

# %%
astronaut
# Out:
# {'name': 'elon', 'suit_size': 'large', 'allergies': 'peanuts'}

# %%
astronaut['space_ship'] = 'Galactic 1'

# %%
astronaut
# Out:
# {'name': 'elon',
#  'suit_size': 'large',
#  'allergies': 'peanuts',
#  'space_ship': 'Galactic 1'}

# %%
# Delete

# %%
del astronaut['space_ship']

# %%
astronaut
# Out:
# {'name': 'elon', 'suit_size': 'large', 'allergies': 'peanuts'}
